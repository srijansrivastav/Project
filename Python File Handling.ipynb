# %%
import pandas as pd

# %%
file_path = "C:/Users/Ryan Faulkner/Downloads/City-simple.tsv"

# %%
file = open(file_path, "r", encoding="utf8")
print(file.read())
# Out:
# URI	rdf-schema#label	country_label	country	populationTotal	wgs84_pos#lat	wgs84_pos#long
# URI	http://www.w3.org/2000/01/rdf-schema#label	http://dbpedia.org/ontology/country	http://dbpedia.org/ontology/country	http://dbpedia.org/ontology/populationTotal	http://www.w3.org/2003/01/geo/wgs84_pos#lat	http://www.w3.org/2003/01/geo/wgs84_pos#long
# URI	XMLSchema#string	XMLSchema#string	Country	XMLSchema#nonNegativeInteger	XMLSchema#float	XMLSchema#float
# http://www.w3.org/2002/07/owl#Thing	http://www.w3.org/2001/XMLSchema#string	http://www.w3.org/2001/XMLSchema#string	http://dbpedia.org/ontology/Country	http://www.w3.org/2001/XMLSchema#nonNegativeInteger	http://www.w3.org/2001/XMLSchema#float	http://www.w3.org/2001/XMLSchema#float
# http://dbpedia.org/resource/Kud	Kud	India	http://dbpedia.org/resource/India	1140	33.08	75.28
# http://dbpedia.org/resource/Kuju,_Hazaribag	Kuju Hazaribag	India	http://dbpedia.org/resource/India	18049	23.72	85.5
# ...

# %%
df = pd.read_csv(file_path, sep="\t", header=0, skiprows=range(1, 4))

# %%
df.head()
# Out:
#                                            URI rdf-schema#label country_label  \
# 0              http://dbpedia.org/resource/Kud              Kud         India
# 1  http://dbpedia.org/resource/Kuju,_Hazaribag   Kuju Hazaribag         India
# 2         http://dbpedia.org/resource/Kumbhraj         Kumbhraj         India
# 3          http://dbpedia.org/resource/Kumhari          Kumhari         India
# 4          http://dbpedia.org/resource/Kundgol          Kundgol         India
#
#                              country populationTotal wgs84_pos#lat  \
# 0  http://dbpedia.org/resource/India            1140         33.08
# 1  http://dbpedia.org/resource/India           18049         23.72
# 2  http://dbpedia.org/resource/India           13999         24.37
# 3  http://dbpedia.org/resource/India           29737         21.27
# 4  http://dbpedia.org/resource/India           16837         15.25
#
#   wgs84_pos#long
# 0          75.28
# 1           85.5
# 2          77.05
# 3          81.52
# ...

# %%
df.columns
# Out:
# Index(['URI', 'rdf-schema#label', 'country_label', 'country',
#        'populationTotal', 'wgs84_pos#lat', 'wgs84_pos#long'],
#       dtype='object')

# %%
df.dtypes
# Out:
# URI                 object
# rdf-schema#label    object
# country_label       object
# country             object
# populationTotal     object
# wgs84_pos#lat       object
# wgs84_pos#long      object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20229 entries, 0 to 20228
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   URI               20229 non-null  object
#  1   rdf-schema#label  20224 non-null  object
#  2   country_label     17588 non-null  object
#  3   country           17591 non-null  object
#  4   populationTotal   17820 non-null  object
#  5   wgs84_pos#lat     18853 non-null  object
#  6   wgs84_pos#long    18852 non-null  object
# dtypes: object(7)
# memory usage: 1.1+ MB

# %%
df["country_label"].unique()
# Out:
# array(['India', 'Netherlands', 'Nigeria', 'Mexico', 'United States', nan,
#        'Thailand', 'Indonesia', 'Benin', 'Ukraine', 'Vietnam', 'Cambodia',
#        'Poltava Oblast', 'Pakistan', 'Azerbaijan',
#        '{Belarus|Dzyarzhynsk Raion|Minsk Region}', 'Bexar County Texas',
#        'Colombia', 'Panama', 'Jordan', 'Northeast Region Brazil',
#        'Republic of Ireland', 'North Korea', 'Kazakhstan',
#        'United Kingdom', 'Liberia', 'Croatia', 'China', 'Australia',
#        'Kosovo', 'Canada', 'Brazil', 'Algeria', 'Ivory Coast', 'Uruguay',
#        'Philippines', 'Iraq', 'Iran', 'Spain', 'Portugal', 'Germany',
#        'Tunisia', 'Tanzania', 'Japan', 'Afghanistan', 'Norway', 'Nepal',
#        'Slovenia', 'Czech Republic', 'Latvia', 'Macedonia', 'Lebanon',
#        'Estonia', 'Hungary', 'Jamaica', 'Greece', 'Namibia', 'Cuba',
#        'Venezuela', 'Austria', 'Serbia', 'Saint Lucia', 'Sri Lanka',
#        'Zimbabwe', 'Ghana', 'Maldives', 'Mozambique', 'Togo', 'Cyprus',
# ...

# %%
df["country_label"].unique().size
# Out:
# 164

# %%
import re

# %%
code = "LTN"
res = re.search("^[A-Z]{3}$", code)
print(res)
# Out:
# <re.Match object; span=(0, 3), match='LTN'>
